# %%
import sys, os, glob

#aponta para a instalação do spark da imagem
os.environ["SPARK_HOME"] = "/usr/local/spark"

#adicionando diretorio dp pyspark ao sys.path
sys.path.append("/usr/local/spark/bin/pyspark")

#adiciobabdo o diretorio py4j do pyspark ao sys.path
sys.path.append("/usr/local/spark-3.5.0-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip")
